# %%
from Classes.tz5 import *
import time

# %%
f = lambda x1, x2: eval('-(cos((x1-0.1)*x2))**2-x1*sin(3*x1+x2)')

# %%
f(1,2)
# Out:
# -0.0516207918329265 - sin(5)

# %% [markdown]
# # Задание 1

# %% [markdown]
# ## Метод Ньютона

# %%
# пример 1
t1 = time.time()
x, y = Newton(func = example1, equality = limit1, x0 = (0.0, 0.0))
t2 = time.time()
print(x, y)
print('Время выполнения: ', t2 - t1)
# Out:
# [0.84839 0.30321] -1.19458
# Время выполнения:  0.05038809776306152

# %%
# пример 2
example2 = 'x1**4+x2**4-2**x1-2*x2**2'
limit2 = ['x1**2-x2**2-7=0']

# %%
t1 = time.time()
x, y = Newton(example2, limit2, (1, 1))
t2 = time.time()
print(x, y)
print('Время выполнения: ', t2 - t1)
# Out:
# [ 2.64575 -0.     ] 42.74178
# Время выполнения:  0.503427267074585

# %%
# пример 3
example3 = '-x1**2+6*x1+x2'
limit3 = ['2*x1+3*x2-24=0', '3*x1+2*x2-24=0']

# %%
t1 = time.time()
x, y = Newton(example3, limit3, (0, 0))
t2 = time.time()
print(x, y)
print('Время выполнения: ', t2 - t1)
# Out:
# [4.8 4.8] 10.56000
# Время выполнения:  0.05205106735229492

# %%
# пример 4
example4 = '(x1-3)**2+(x2-4)**2'
limit4 = ['-3*x1-2*x2-7=0', '3*x1+2*x2+6=0']

# %%
t1 = time.time()
x, y = Newton(example4, limit4, (5, 1))
t2 = time.time()
print(x, y)
print('Время выполнения: ', t2 - t1)
# Out:
# [3. 4.] 0.0
# Время выполнения:  0.6086719036102295

# %%
# пример 5
example5 = '29*x1**2-54*x1*x2+26*x2**2'
limit5 = ['3*x1-4*x2-1=0']

# %%
t1 = time.time()
x, y = Newton(example5, limit5, (0.5, 0.5))
t2 = time.time()
print(x, y)
print('Время выполнения: ', t2 - t1)
# Out:
# [-0.6 -0.7] 0.50000
# Время выполнения:  0.09166097640991211

# %% [markdown]
# ## Метод логарифмических барьеров

# %%
example1 = 'x1**3+x2**2+2*x1*x2'
limit1 = ['2*x1+x2-2-4<=0']

# %%
t1 = time.time()
x, y = logBarMethod(example1, limit1, (0, 0), max_steps=100)
t2 = time.time()
print(x, y)
print('Время выполнения: ', t2 - t1)
# Out:
# [ 0.09259167 -0.18518333] 0.000793808426291088
# Время выполнения:  0.20742392539978027

# %%
# пример 2
example2 = 'x1**4+x2**4-2**x1-2*x2**2'
limit2 = ['x1**2-x2**2-7>=0']

# %%
t1 = time.time()
x, y = logBarMethod(example2, limit2, (1,1), max_steps=10)
t2 = time.time()
print(x, y)
print('Время выполнения: ', t2 - t1)
# Out:
# [-1.38685321  1.03769663] 2.322823193010888
# Время выполнения:  19.531380891799927

# %%
# пример 3
example3 = '-x1**2+6*x1+x2'
limit3 = ['2*x1+3*x2>=24', '3*x1+2*x2<=24']

# %%
t1 = time.time()
x, y = logBarMethod(example3, limit3, (0, 0), max_steps=100)
t2 = time.time()
print(x, y)
print('Время выполнения: ', t2 - t1)
# Out:
# [0 0] 0
# Время выполнения:  0.14131593704223633

# %%
# пример 4
example4 = '(x1-3)**2+(x2-4)**2'
limit4 = ['-3*x1-2*x2-6<=1', '3*x1+2*x2+6<=0']

# %%
t1 = time.time()
x, y = logBarMethod(example4, limit4, (0, 0), max_steps=100)
t2 = time.time()
print(x, y)
print('Время выполнения: ', t2 - t1)
# Out:
# [299.22790689 399.48527126] 244159.57260871117
# Время выполнения:  5.38426399230957

# %%
# пример 5
example5 = '29*x1**2-54*x1*x2+26*x2**2'
limit5 = ['3*x1-4*x2<=1']

# %%
t1 = time.time()
x, y = logBarMethod(example5, limit5, (0.5, 0.5), max_steps=100)
t2 = time.time()
print(x, y)
print('Время выполнения: ', t2 - t1)
# Out:
# [-48.8228375  -48.70997708] 2395.020967231947
# Время выполнения:  2.7007322311401367

# %% [markdown]
# ## Прямо-двойственный метод

# %%
# Пример 1
example1 = 'x1**3+x2**2+2*x1*x2'
limit1 = ['2*x1+x2-6<=0']
t1 = time.time()
x, y = inequality(example1, limit1,[0,0])
t2 = time.time()
print(x, y)
print('Время выполнения: ', t2 - t1)
# Out:
# [ 0.08333333 -0.16666667] 0.0005787037037037028
# Время выполнения:  0.07682204246520996

# %%
# пример 2
example2 = 'x1**4+x2**4-2**x1-2*x2**2'
limit2 = ['x1**2-x2-7<=0']
t1 = time.time()
x, y = inequality(example2, limit2, [0,0])
t2 = time.time()
print(x, y)
print('Время выполнения: ', t2 - t1)
# Out:
# [ 0.45615383 -0.03703704] -1.3313254100962737
# Время выполнения:  0.23349785804748535

# %%
# пример 3
example3 = '-x1**2+6*x1+x2'
limit3 = ['3*x1+2*x2-24<=0']
t1 = time.time()
x, y = inequality(example3, limit3,[0,0])
t2 = time.time()
print(x, y)
print('Время выполнения: ', t2 - t1)
# Out:
# [ 2.25  -9.875] -1.4375
# Время выполнения:  0.05481600761413574

# %%
# пример 4
example4 = '(x1-3)**2+(x2-4)**2'
limit4 = ['-3*x1-2*x2-7<=0']
t1 = time.time()
x, y = inequality(example4, limit4,[0,0])
t2 = time.time()
print(x, y)
print('Время выполнения: ', t2 - t1)
# Out:
# [1.22222222 2.81481481] 4.5651577503429355
# Время выполнения:  0.07903385162353516

# %%
# пример 5
example5 = '29*x1**2-54*x1*x2+26*x2**2'
limit5 = ['3*x1-4*x2-1<=0']
t1 = time.time()
x, y = inequality(example5, limit5,[0,0])
t2 = time.time()
print(x, y)
print('Время выполнения: ', t2 - t1)
# Out:
# [0.3  0.35] 0.125
# Время выполнения:  0.05500602722167969

# %% [markdown]
# # Задание 2

# %%
example3 = '-x1**2+6*x1+x2'
limit3 = ['2*x1+3*x2-24=0', '3*x1+2*x2-24=0']
result = Newton(example3, limit3, (0, 0))
visualize3d(example4, ['2*x1+3*x2-24', '3*x1+2*x2-24'], result).show()

# %%
result
# Out:
# (array([4.8, 4.8]), 10.56000)
